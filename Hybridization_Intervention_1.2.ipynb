# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2>3. Jupyter Notebooks and Color Scheme Explained</h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <div style = 'background-color:gainsboro'>Jupyter notebook is a free open-source software that allows users to share computational documents, which is what this document is. We will be using the computational method of modeling, which is the act of creating a visual representation of a complex system, to support our understanding of said system. The system in question today is hybridization.</div>

# %% [markdown]
# <div style = 'background-color:gainsboro'>As you can see, sections are color-coded. Information that is meant to be read will be in this grey color.</div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>Sections that will require you to type a response will be in this green color.</div>

# %% [markdown]
# <div style = 'background-color:rgb(220,205,125)'>Sections that will require you to answer on the worksheet will be in this yellow color</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>And sections that will require you to code or execute a cell will be in this blue color.</div>

# %% [markdown]
# <div style = 'background-color:rgb(159,074,150)'><font color='white'> You may have noticed you can click on the cells and see some texts with code, but cannot change anything. This is a useful feature to have for general applications of Jupyter notebook, but not as useful for our purposes. When you click on cells that can't be changed, just execute the cell (press the shift and enter key simultaneously) and move on the next cell.</font></div>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2> 4. Getting used to Jupyter Notebooks </h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'> Please enter your Name and Student ID in the following cell so the researchers pair your Jupyter notebook with your Hybridization Worksheet.</div>

# %% [markdown]
# Name: {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# Student ID#: {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# Student email: {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:gainsboro'> <center><h2><b>How to Execute a cell</b></h2></center>
# <div style = 'background-color:gainsboro'><ul>
#     <li>Executing a cell means activating the code in the cell. Executing a cell after your have typed in the cell also publishes your text to the notebook, which is how you will answer questions in this activity.</li>
#     <li>To execute a cell you need to press the shift key and enter key. If you are a Mac user, you need to press the shift key and return key.</li>
#     <li> You can also execute a cell by clicking on the play button to the left of the cell you wish to execute.</li></div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'><ul>
#     <li><h4>Now click on the next cell and execute the cell</h4></li></div>

# %%
# if Windows computer press the shift key and enter key at the same time
# if Mac computer press the shift key and return key at the same time
def execute_a_cell():
    #print function with message inside
    print("Great! Let's get started with the activity.") #if you want to output a different message, feel free to delete and replace the words Great! Let's get started with the activity.
# the function we just defined in the same cell. Later you will have to type the function
execute_a_cell()

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2> 5. Student Objectives and Your Thoughts/Ideas/Recollections</h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# **<div style = 'background-color:gainsboro'> <center>Student Objectives</div>**
# <div style = 'background-color:gainsboro'><ul>
#     <li>Students will learn what covalent bonds are associated with sp<sup>3</sup>, sp<sup>2</sup> and sp hybrid orbitals.</li>
#     <li>Students should learn how to "call" a function to practice code application specific to chemical problems.</li>
#     <li>Students will use different models of representation (2D-flat, 2D-depth, 3D-static, and 3D-interactive) to visualize hybrid orbitals.</li>
#     <li>Students will analyze model application as they answer questions throughout the activity.</li></div>

# %% [markdown]
# ### <div style = 'background-color:rgb(093,168,153)'> <center> Student Response: Stop and Jot</div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'> In the cell below, write two to three sentences providing your thoughts, ideas, and what you remember about hybridization and orbitals.<br>
# There are no right answers<br>
#  </div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(220,205,125)'> <b>Move to Document 2: Hybridization worksheet, Section 5.1 Illustration Box 1</b>, please draw a diagram of an s orbital, a p orbital, and a hybrid orbital. Then come back to your jupyter notebook and progress to Section 6. Coding Practice.</div>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2>6. Coding Practice</h2>

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### <div style = 'background-color:gainsboro'><center>Short Coding Familiarity</div>

# %% [markdown]
# <div style = 'background-color:gainsboro'>In the following cell you will import libraries, a collection of functions, that were used to build the code you will be applying.<br>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'><h4>Execute the following cell to import the libraries we need.</h4></div>

# %%
# Here we are importing necessary libraries to build the code we need to visualize our representational models
import pandas as pd
from jupyter_jsmol import JsmolView
from ipywidgets import Layout, widgets, interact
from IPython.display import display, SVG
from IPython.display import Image
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import rdMolDraw2D
from bs4 import BeautifulSoup
import math
import Spatial_think_visualize as stv

# %% [markdown]
# ### <div style = 'background-color:gainsboro'><center>Practice</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>Now that the cells we need have been executed and are active, we can call our first function to visualize an s orbital on one carbon of an ethene molecule.<br>
# Look at your worksheet Functions Table, and execute the example_code_s_orbital function.</div>

# %% [markdown]
# <div style = 'background-color:gainsboro'>Note: The coloring scheme applied to the atoms is a popular coloring scheme used when applying computational methods<br></div>
#
# <p style="font-size:18px">
# <font color='grey'>Carbons are grey</font><br>
# <font color='blue'>Nitrogens are blue</font><br>
# Hydrogens are white (colorscheme is not being used here due to colorblindness considerations)<br>
# <font color='red'>Oxygens are red</font></div>
# </p>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>Now we will visualize a p orbital on the same carbon atom of the ethene molecule.<br>
# Look at your worksheet Functions Table, and execute the example_code_p_orbital function.<br>
# You will need to click on the image to rotate the molecule to see the p orbital.</div>

# %% [markdown]
# <div style = 'background-color:gainsboro'>Note: The double bond also rotates, which is a bug, and doesn't reflect reality. To the researcher's knowledge, this is the only object that rotates when <i>it should not</i>.<br>
# Double and triple bonds do not rotate as depicted</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>Now we will visualize both s and p orbital on the same carbon atom of the ethene molecule.<br>
# Look at your worksheet Functions Table, and execute the example_code_overlayed_orbital.<br></div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>To see the difference of a p orbital and a hybrid orbital, we will visualize one portion of a hybrid orbital.<br>
# Look at your worksheet Functions Table, and execute the example_code_hybridized_orbital.</div>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2>7. Orbitals and Hybridization</h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <div style = 'background-color:gainsboro'> <center>Orbitals</div>

# %% [markdown]
# <div style = 'background-color:gainsboro'>Due to electron's wave-particle duality, we can describe the discrete energy level where the electron can exist in an atom with its wavefunction 𝛹. Since wavefunctions are a function of spatial location, we can square the wavefunction (𝛹<sup>2</sup>) to show the probability of finding the electron in said location, also refered to as an electron cloud. To visualize this probability distribution we can generate an image of the atomic orbitals by plotting a three-dimensional plot of 𝛹<sup>2</sup>
#
# >Organic chemistry primarily deals with first-and second-row elements (H, C, N, O), so we can focus on the 1s, 2s, and three 2p (2p<sub>x</sub>, 2p<sub>y</sub>, 2p<sub>z</sub>) orbitals.<br>![Screenshot 2024-08-09 at 5.44.56 PM.png](attachment:9911e2c9-2eba-41fa-8e13-82f3b53dd016.png)
#
# >Chemists use an energy diagram to represent relative energy levels of said atomic orbitals.<br>
# ![Screenshot 2024-08-09 at 5.51.16 PM.png](attachment:9e4f7b3c-7308-4e50-8101-7ee061cde72a.png)<br>
# Degenerate orbitals are orbitals with the same energy level, like the three 2p orbitals.</div>

# %% [markdown]
# # <div style = 'background-color:gainsboro'> <center>Hybridization</div>

# %% [markdown]
# <div style = 'background-color:gainsboro'> Valence Bond Theory, the theory that an electron from each atom are shared to form a covalent bond, was produced before the theory of quantum mechanics was established, and thus was incomplete. Hybridization was developed to incorporate quantum mechanics to help explain the shapes of molecules that were observed from experimentation.<br>
# Hybridization is a mathematical averaging of atomic orbitals s and p, which allowed chemists to understand bond strength, bond rotation, bond geometry, resonance and chemical magnetism. In this activity, we will be focusing on bond geometry to qualitatively understand electron behavior.<br>
# Students often struggle to understand hybridization because they unproductively apply Valence Shell Electron Pair Repulsion (VSEPR) theory to determine electron structure. VSEPR theory does not account for the stabilizing quantum mechanical effects of orbital overlap, and overly relies on electron-pair repulsion.</div>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2>8. Methylamine</h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'><center>Visualizing Methylamine CH<sub>3</sub>NH<sub>2</sub></div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 2D flat representation of Methylamine.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 2D depth representation of Methylamine. </div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 3D static representation of Methylamine.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 3D interactive representation of Methylamine.</div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'><center>Student open response </div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>In the cell below explain what the forms of representation (2D-flat, 2D-depth, 3D-static, 3D-interactive), allow for a better understanding of sp<sup>3</sup> hybridization in Methylamine CH<sub>3</sub>NH<sub>2</sub>?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the strengths of the representations chosen?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the limitations of the representations chosen?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What orbital(s), hybridized or unhybridized, form the 𝜎 bond (single bond) between the carbon and nitrogen of Methylamine?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the effects of hybridization on the dipole moment in Methylamine? </div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>In your words explain what sp<sup>3</sup> hybridization is.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2>9. Formaldeyde</h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'><center>Visualizing Formaldehyde CH<sub>2</sub>O.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 2D flat representation of Formaldehyde.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 2D depth representation of Formaldehyde.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 3D static representation of Formaldehyde.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 3D interactive representation of Formaldehyde.</div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'><center>Student open response </div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>In the cell below explain what the forms of representation (2D-flat, 2D-depth, 3D-static, 3D-interactive), allow for a better understanding of sp<sup>2</sup> hybridization in Formaldehyde CH<sub>2</sub>O?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the strengths of the representations chosen?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the limitations of the representations chosen?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What orbital(s), hybridized or unhybridized, form the 𝜎 bond (single bond) between the carbon and oxygen of Formaldehyde?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What orbital(s), hybridized or unhybridized, form the 𝜋 bond (double bond) between the carbon and oxygen of Formaldehyde?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the effects of hybridization on the dipole moment in Formaldehyde?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>In your words explain what sp<sup>2</sup> hybridization is.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2>10. Acetonitrile</h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'><center>Visualizing Acetonitrile C<sub>2</sub>H<sub>3</sub>N.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 2D flat representation of Acetonitrile. </div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 2D depth representation of Acetonitrile. </div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 3D static representation of Acetonitrile.</div>

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>In the cell below please call the funtion that produces a 3D interactive representation of Acetonitrile.</div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'><center>Student open response </div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>In the cell below explain what the forms of representation (2D-flat, 2D-depth, 3D-static, 3D-interactive), allow for a better understanding of sp hybridization in Acetonitrile C<sub>2</sub>H<sub>3</sub>N?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the strengths of the representations chosen?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the limitations of the representations chosen?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What orbital(s), hybridized or unhybridized, form the 𝜎 bond (single bond) between the carbon and nitrogen of Acetonitrile?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What orbital(s), hybridized or unhybridized, form the first 𝜋 bond (double bond) between the carbon and nitrogen of Acetonitrile?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What orbital(s), hybridized or unhybridized, form the second 𝜋 bond (double bond) between the carbon and nitrogen of Acetonitrile?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What are the effects of hybridization on the dipole moment in Acetonitrile?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>In your words explain what sp hybridization is.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# ---
# ---

# %% [markdown]
# <center><h2>11. Technical questions</h2></center>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'><center>Final Questions</div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>Is there a difference in bond lengths of single, double, and triple bonds? Please explain your reasoning.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(148,203,236)'>Determine what representational model you would use to determine the hybridization state of the central carbon and terminal carbon in allene C<sub>3</sub>H<sub>4</sub>. Cells are provided below to visualize as many or as few models as needed.</div>

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>What representational model do you prefer to use for Allene? Please state below.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'>Specify why you selected this representational model.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'> If you were tasked with convincing another chemistry student to use the representational model you chose, how would you convince them?</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'> Identify the hybridizaiton state of the central carbon in Allene and explain your reasoning.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# <div style = 'background-color:rgb(093,168,153)'> Identify the hybridizaiton state of a terminal carbon in Allene and explain your reasoning.</div>

# %% [markdown]
# {click in this cell, delete text in curly brackets, add your text}

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <center>12. Your Thoughts/Ideas/Understandings

# %% [markdown]
# ---
# ---

# %% [markdown]
# <div style = 'background-color:rgb(220,205,125)'><b>Move to Document 2: Hybridization worksheet, Section 12.1 Illustration Box 2</b>, please draw a diagram of Allene. You need to include the hybridization state of the central and terminal carbon and specify which bonds are sigma 𝜎 and pi 𝜋. If lonepairs exist, you need to include those in your model.</div>
